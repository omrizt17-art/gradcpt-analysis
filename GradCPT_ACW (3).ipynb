# %%
# !pip install -q mne numpy scipy pandas matplotlib seaborn
# !pip install -q mne pyvista pyvistaqt ipywidgets seaborn pymatreader


import os, glob
import mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from scipy.signal import welch, correlate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 25.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 48.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.5/134.5 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 86.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.0/273.0 kB 15.5 MB/s eta 0:00:00

# %%
# ============================================================
# 0) COLAB + DRIVE SETUP
#    - Mount Drive
#    - Define a project root
#    - Make MNE downloads persistent (fsaverage, etc.)
# ============================================================

from google.colab import drive
import os

drive.mount("/content/drive")

# Project root folder in Drive
PROJECT_DIR = "/content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized"
os.makedirs(PROJECT_DIR, exist_ok=True)



print("PROJECT_DIR:", PROJECT_DIR)
# Out:
# Mounted at /content/drive
# PROJECT_DIR: /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized

# %%
#location to save results
import os

RESULTS_DIR = "/content/drive/MyDrive/GRAD_OFF/acw_results"
os.makedirs(RESULTS_DIR, exist_ok=True)
print("Results folder:", RESULTS_DIR)
# Out:
# Results folder: /content/drive/MyDrive/GRAD_OFF/acw_results

# %%
# ============================================================
# A) INPUTS: data folder + which files to run
# ============================================================

import glob

DATA_DIR = PROJECT_DIR
set_files = sorted(glob.glob(os.path.join(DATA_DIR, "sub-*_run-1_preproc_raw.fif")))
print("Found", len(set_files), "GRADOFF files")
print("Example files:", set_files[:3])

# sanity check a single file
if len(set_files) > 0:
    print("First file exists:", os.path.exists(set_files[0]))
# Out:
# Found 28 GRADOFF files
# Example files: ['/content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-001_run-1_preproc_raw.fif', '/content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-002_run-1_preproc_raw.fif', '/content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-004_run-1_preproc_raw.fif']
# First file exists: True

# %%
# sanity check: print all matched filenames in full to confirm they're all genuine gradCPT files
print(f"Total files matched: {len(set_files)}\n")
for f in set_files:
    print(os.path.basename(f))
# Out:
# Total files matched: 28
#
# sub-001_run-1_preproc_raw.fif
# sub-002_run-1_preproc_raw.fif
# sub-004_run-1_preproc_raw.fif
# sub-005_run-1_preproc_raw.fif
# sub-006_run-1_preproc_raw.fif
# sub-007_run-1_preproc_raw.fif
# sub-008_run-1_preproc_raw.fif
# sub-009_run-1_preproc_raw.fif
# sub-010_run-1_preproc_raw.fif
# sub-011_run-1_preproc_raw.fif
# sub-012_run-1_preproc_raw.fif
# sub-013_run-1_preproc_raw.fif
# sub-014_run-1_preproc_raw.fif
# sub-015_run-1_preproc_raw.fif
# sub-016_run-1_preproc_raw.fif
# sub-017_run-1_preproc_raw.fif
# sub-018_run-1_preproc_raw.fif
# sub-019_run-1_preproc_raw.fif
# sub-020_run-1_preproc_raw.fif
# sub-021_run-1_preproc_raw.fif
# sub-022_run-1_preproc_raw.fif
# sub-023_run-1_preproc_raw.fif
# sub-024_run-1_preproc_raw.fif
# sub-025_run-1_preproc_raw.fif
# sub-026_run-1_preproc_raw.fif
# sub-027_run-1_preproc_raw.fif
# sub-028_run-1_preproc_raw.fif
# sub-029_run-1_preproc_raw.fif

# %%
# helper functions
import numpy as np
#
CONDITION = "GRADCPT"
def compute_acw(signal, sfreq):
    signal = np.asarray(signal, dtype=float)
    signal = signal - np.mean(signal)

    if np.allclose(signal, 0):
        return np.nan

    acf = np.correlate(signal, signal, mode='full')
    acf = acf[acf.size // 2:]

    if acf[0] == 0:
        return np.nan

    acf = acf / acf[0]

    below = np.where(acf < 0.5)[0]
    if len(below) == 0:
        return np.nan

    lag = below[0]
    acw = lag / sfreq
    return acw


def compute_acw_sliding(raw, window_sec=5, step_sec=1):
    """Compute ACW per EEG channel for each sliding window."""
    data = raw.get_data(picks='eeg')
    sfreq = raw.info['sfreq']

    window = int(window_sec * sfreq)
    step = int(step_sec * sfreq)
    n_samples = data.shape[1]

    acw_epochs = []

    for start in range(0, n_samples - window + 1, step):
        stop = start + window
        segment = data[:, start:stop]

        acw_channels = []
        for ch in segment:
            acw = compute_acw(ch, sfreq)
            acw_channels.append(acw)

        acw_epochs.append(acw_channels)

    return np.array(acw_epochs)


def summarize_acw_epochs(acw_epochs):
    mean_per_window = np.nanmean(acw_epochs, axis=1)   # ACW over time (avg across channels)
    mean_per_channel = np.nanmean(acw_epochs, axis=0)  # ACW over space (avg across windows)
    grand_mean = np.nanmean(acw_epochs)                # overall ACW (avg over everything)
    return mean_per_window, mean_per_channel, grand_mean

# %%
# ============================================================
# D) SUBJECT LOOP: compute ROI timescales per subject
# ============================================================

all_subject_dfs = []  # collects each subject's df_tiw

for path_ec in set_files:

    print("\n====================================================")
    print("Processing:", os.path.basename(path_ec))
    print("====================================================")

    # ------------------------------------------------------------
    # 1) Load EEG
    # ------------------------------------------------------------
    raw = mne.io.read_raw_fif(path_ec, preload=True)
    print(raw)

    if "ECG" in raw.ch_names:
        raw.set_channel_types({"ECG": "ecg"})

    # ------------------------------------------------------------
    # 2) Resample to 128 Hz
    # ------------------------------------------------------------
    raw.resample(128)
    sfreq = raw.info['sfreq']
    print("New sampling rate =", sfreq)
    # ------------------------------------------------------------
    # 3) ACW per channel per window
    # ------------------------------------------------------------
    epochs_acw = mne.make_fixed_length_epochs(
        raw,
        duration=5.0,
        overlap=4.0,   # 5s window with 1s step
        preload=True
    )
    # channel-level loop
    ch_names = [epochs_acw.ch_names[i] for i in mne.pick_types(epochs_acw.info, eeg=True, exclude='bads')] #getting the names of good channels
    n_channels = len(ch_names)
    n_windows = len(epochs_acw)

    # shape: (n_windows, n_channels)
    acw_epochs = np.full((n_windows, n_channels), np.nan) #creating windows per channels metrix

    for wi, epoch in enumerate(epochs_acw.get_data(picks='eeg')):
        # epoch shape: (n_channels, n_times)
        for ci in range(n_channels):
            sig = epoch[ci, :] #selecting the channel
            acw_epochs[wi, ci] = compute_acw(sig, sfreq) #computing acw for channel in specific time window

    acw_mean_per_window, acw_mean_per_channel, acw_grand_mean = summarize_acw_epochs(acw_epochs)
    acw_std_per_channel = np.nanstd(acw_epochs, axis=0)
    ACW = {ch: acw_mean_per_channel[ci] for ci, ch in enumerate(ch_names)}
    ACW_std = {ch: acw_std_per_channel[ci]  for ci, ch in enumerate(ch_names)}
    # ------------------------------------------------------------
    # 4) Build per-subject ACW dataframes + save + append
    # ------------------------------------------------------------
    sub_id = os.path.basename(path_ec).split("_")[0]
    results = []
    for ch in ch_names:
        results.append({
            "Subject":           sub_id,
            "Condition":         CONDITION,
            "Channel":           ch,
            "ACW_mean_s":        ACW[ch],
            "ACW_std_s":         ACW_std[ch],
            "ACW_grand_mean_s":  acw_grand_mean
        })

    df_acw = pd.DataFrame(results)
    df_acw.to_csv(os.path.join(RESULTS_DIR, f"ACW_{sub_id}_{CONDITION}.csv"), index=False)
    all_subject_dfs.append(df_acw)

    # ---- File 2: ACW per window per channel (long format) ----
    rows = []
    for wi in range(n_windows):
        for ci, ch in enumerate(ch_names):
            rows.append({
                "Subject":   sub_id,
                "Condition": CONDITION,
                "Window":    wi,
                "Channel":   ch,
                "ACW_s":     acw_epochs[wi, ci]
            })

    df_acw_windows = pd.DataFrame(rows)
    df_acw_windows.to_csv(os.path.join(RESULTS_DIR, f"ACW_windows_{sub_id}_{CONDITION}.csv"), index=False)
# Out:
# ====================================================
# Processing: sub-001_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-001_run-1_preproc_raw.fif...
#     Range : 0 ... 1120899 =      0.000 ...   224.180 secs
# Ready.
# Reading 0 ... 1120899  =      0.000 ...   224.180 secs...
# <Raw | sub-001_run-1_preproc_raw.fif, 64 x 1120900 (224.2 s), ~547.4 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 220 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 220 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-002_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-002_run-1_preproc_raw.fif...
#     Range : 0 ... 1209999 =      0.000 ...   242.000 secs
# Ready.
# Reading 0 ... 1209999  =      0.000 ...   242.000 secs...
# <Raw | sub-002_run-1_preproc_raw.fif, 64 x 1210000 (242.0 s), ~590.9 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 238 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 238 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-004_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-004_run-1_preproc_raw.fif...
#     Range : 0 ... 1096499 =      0.000 ...   219.300 secs
# Ready.
# Reading 0 ... 1096499  =      0.000 ...   219.300 secs...
# <Raw | sub-004_run-1_preproc_raw.fif, 64 x 1096500 (219.3 s), ~535.5 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 215 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 215 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-005_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-005_run-1_preproc_raw.fif...
#     Range : 0 ... 1244899 =      0.000 ...   248.980 secs
# Ready.
# Reading 0 ... 1244899  =      0.000 ...   248.980 secs...
# <Raw | sub-005_run-1_preproc_raw.fif, 64 x 1244900 (249.0 s), ~607.9 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 244 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 244 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-006_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-006_run-1_preproc_raw.fif...
#     Range : 0 ... 1389499 =      0.000 ...   277.900 secs
# Ready.
# Reading 0 ... 1389499  =      0.000 ...   277.900 secs...
# <Raw | sub-006_run-1_preproc_raw.fif, 64 x 1389500 (277.9 s), ~678.5 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 273 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 273 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-007_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-007_run-1_preproc_raw.fif...
#     Range : 0 ... 1666799 =      0.000 ...   333.360 secs
# Ready.
# Reading 0 ... 1666799  =      0.000 ...   333.360 secs...
# <Raw | sub-007_run-1_preproc_raw.fif, 64 x 1666800 (333.4 s), ~813.9 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 329 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 329 events and 640 original time points ...
# 3 bad epochs dropped
#
# ====================================================
# Processing: sub-008_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-008_run-1_preproc_raw.fif...
#     Range : 0 ... 1284399 =      0.000 ...   256.880 secs
# Ready.
# Reading 0 ... 1284399  =      0.000 ...   256.880 secs...
# <Raw | sub-008_run-1_preproc_raw.fif, 64 x 1284400 (256.9 s), ~627.2 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 252 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 252 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-009_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-009_run-1_preproc_raw.fif...
#     Range : 0 ... 1249099 =      0.000 ...   249.820 secs
# Ready.
# Reading 0 ... 1249099  =      0.000 ...   249.820 secs...
# <Raw | sub-009_run-1_preproc_raw.fif, 64 x 1249100 (249.8 s), ~610.0 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 245 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 245 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-010_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-010_run-1_preproc_raw.fif...
#     Range : 0 ... 1071799 =      0.000 ...   214.360 secs
# Ready.
# Reading 0 ... 1071799  =      0.000 ...   214.360 secs...
# <Raw | sub-010_run-1_preproc_raw.fif, 64 x 1071800 (214.4 s), ~523.4 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 210 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 210 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-011_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-011_run-1_preproc_raw.fif...
#     Range : 0 ... 1481699 =      0.000 ...   296.340 secs
# Ready.
# Reading 0 ... 1481699  =      0.000 ...   296.340 secs...
# <Raw | sub-011_run-1_preproc_raw.fif, 64 x 1481700 (296.3 s), ~723.6 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 292 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 292 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-012_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-012_run-1_preproc_raw.fif...
#     Range : 0 ... 1175399 =      0.000 ...   235.080 secs
# Ready.
# Reading 0 ... 1175399  =      0.000 ...   235.080 secs...
# <Raw | sub-012_run-1_preproc_raw.fif, 64 x 1175400 (235.1 s), ~574.0 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 231 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 231 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-013_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-013_run-1_preproc_raw.fif...
#     Range : 0 ... 1240299 =      0.000 ...   248.060 secs
# Ready.
# Reading 0 ... 1240299  =      0.000 ...   248.060 secs...
# <Raw | sub-013_run-1_preproc_raw.fif, 64 x 1240300 (248.1 s), ~605.7 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 244 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 244 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-014_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-014_run-1_preproc_raw.fif...
#     Range : 0 ... 1377099 =      0.000 ...   275.420 secs
# Ready.
# Reading 0 ... 1377099  =      0.000 ...   275.420 secs...
# <Raw | sub-014_run-1_preproc_raw.fif, 64 x 1377100 (275.4 s), ~672.5 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 271 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 271 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-015_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-015_run-1_preproc_raw.fif...
#     Range : 0 ... 1181599 =      0.000 ...   236.320 secs
# Ready.
# Reading 0 ... 1181599  =      0.000 ...   236.320 secs...
# <Raw | sub-015_run-1_preproc_raw.fif, 64 x 1181600 (236.3 s), ~577.0 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-016_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-016_run-1_preproc_raw.fif...
#     Range : 0 ... 1189699 =      0.000 ...   237.940 secs
# Ready.
# Reading 0 ... 1189699  =      0.000 ...   237.940 secs...
# <Raw | sub-016_run-1_preproc_raw.fif, 64 x 1189700 (237.9 s), ~581.0 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 233 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 233 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-017_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-017_run-1_preproc_raw.fif...
#     Range : 0 ... 1089599 =      0.000 ...   217.920 secs
# Ready.
# Reading 0 ... 1089599  =      0.000 ...   217.920 secs...
# <Raw | sub-017_run-1_preproc_raw.fif, 64 x 1089600 (217.9 s), ~532.1 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 213 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 213 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-018_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-018_run-1_preproc_raw.fif...
#     Range : 0 ... 1046999 =      0.000 ...   209.400 secs
# Ready.
# Reading 0 ... 1046999  =      0.000 ...   209.400 secs...
# <Raw | sub-018_run-1_preproc_raw.fif, 64 x 1047000 (209.4 s), ~511.3 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 205 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 205 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-019_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-019_run-1_preproc_raw.fif...
#     Range : 0 ... 1061599 =      0.000 ...   212.320 secs
# Ready.
# Reading 0 ... 1061599  =      0.000 ...   212.320 secs...
# <Raw | sub-019_run-1_preproc_raw.fif, 64 x 1061600 (212.3 s), ~518.4 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 208 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 208 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-020_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-020_run-1_preproc_raw.fif...
#     Range : 0 ... 1271299 =      0.000 ...   254.260 secs
# Ready.
# Reading 0 ... 1271299  =      0.000 ...   254.260 secs...
# <Raw | sub-020_run-1_preproc_raw.fif, 64 x 1271300 (254.3 s), ~620.8 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 250 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 250 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-021_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-021_run-1_preproc_raw.fif...
#     Range : 0 ... 1206399 =      0.000 ...   241.280 secs
# Ready.
# Reading 0 ... 1206399  =      0.000 ...   241.280 secs...
# <Raw | sub-021_run-1_preproc_raw.fif, 64 x 1206400 (241.3 s), ~589.1 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 237 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 237 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-022_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-022_run-1_preproc_raw.fif...
#     Range : 0 ... 1137999 =      0.000 ...   227.600 secs
# Ready.
# Reading 0 ... 1137999  =      0.000 ...   227.600 secs...
# <Raw | sub-022_run-1_preproc_raw.fif, 64 x 1138000 (227.6 s), ~555.7 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 223 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 223 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-023_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-023_run-1_preproc_raw.fif...
#     Range : 0 ... 1056099 =      0.000 ...   211.220 secs
# Ready.
# Reading 0 ... 1056099  =      0.000 ...   211.220 secs...
# <Raw | sub-023_run-1_preproc_raw.fif, 64 x 1056100 (211.2 s), ~515.7 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 207 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 207 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-024_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-024_run-1_preproc_raw.fif...
#     Range : 0 ... 1266299 =      0.000 ...   253.260 secs
# Ready.
# Reading 0 ... 1266299  =      0.000 ...   253.260 secs...
# <Raw | sub-024_run-1_preproc_raw.fif, 64 x 1266300 (253.3 s), ~618.4 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 249 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 249 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-025_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-025_run-1_preproc_raw.fif...
#     Range : 0 ... 1108299 =      0.000 ...   221.660 secs
# Ready.
# Reading 0 ... 1108299  =      0.000 ...   221.660 secs...
# <Raw | sub-025_run-1_preproc_raw.fif, 64 x 1108300 (221.7 s), ~541.2 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 217 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 217 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-026_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-026_run-1_preproc_raw.fif...
#     Range : 0 ... 1044799 =      0.000 ...   208.960 secs
# Ready.
# Reading 0 ... 1044799  =      0.000 ...   208.960 secs...
# <Raw | sub-026_run-1_preproc_raw.fif, 64 x 1044800 (209.0 s), ~510.2 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 204 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 204 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-027_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-027_run-1_preproc_raw.fif...
#     Range : 0 ... 1084399 =      0.000 ...   216.880 secs
# Ready.
# Reading 0 ... 1084399  =      0.000 ...   216.880 secs...
# <Raw | sub-027_run-1_preproc_raw.fif, 64 x 1084400 (216.9 s), ~529.6 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 212 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 212 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-028_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-028_run-1_preproc_raw.fif...
#     Range : 0 ... 1310299 =      0.000 ...   262.060 secs
# Ready.
# Reading 0 ... 1310299  =      0.000 ...   262.060 secs...
# <Raw | sub-028_run-1_preproc_raw.fif, 64 x 1310300 (262.1 s), ~639.9 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 258 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 258 events and 640 original time points ...
# 0 bad epochs dropped
#
# ====================================================
# Processing: sub-029_run-1_preproc_raw.fif
# ====================================================
# Opening raw data file /content/drive/MyDrive/GRAD_OFF/Raw_files/preprocessed_organized/cleaned_organized/sub-029_run-1_preproc_raw.fif...
#     Range : 0 ... 1310299 =      0.000 ...   262.060 secs
# Ready.
# Reading 0 ... 1310299  =      0.000 ...   262.060 secs...
# <Raw | sub-029_run-1_preproc_raw.fif, 64 x 1310300 (262.1 s), ~639.9 MiB, data loaded>
# New sampling rate = 128.0
# Not setting metadata
# 258 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 258 events and 640 original time points ...
# 0 bad epochs dropped

# %%
# ============================================================
# E) GROUP-LEVEL: concatenate subjects, compute ROI means, and plot
# ============================================================

# ------------------------------------------------------------
# 1) Concatenate all subjects into a single dataframe
# ------------------------------------------------------------
df_all = pd.concat(all_subject_dfs, ignore_index=True)
df_all["Condition"] = CONDITION
df_all.to_csv(os.path.join(RESULTS_DIR, f"ACW_ALL_SUBJECTS_{CONDITION}.csv"), index=False)
print("\n================ GROUP-LEVEL SUMMARY ================")
print("Rows in df_all:", len(df_all))
print("Unique subjects in df_all:", df_all["Subject"].nunique())
print("First few subjects:", sorted(df_all["Subject"].unique())[:10], "...")
print("=====================================================\n")

print(df_all.head())


# ------------------------------------------------------------
# 2) channel-level means across subjects (ACW only)
# ------------------------------------------------------------
# df_all has ACW_mean_s and ACW_std_s per subject per channel
df_mean = (
    df_all.groupby(["Condition", "Channel"], as_index=False)
          .agg(
              ACW_mean_s       = ("ACW_mean_s",  "mean"),
              ACW_std_s        = ("ACW_std_s",   "mean"),   # mean of per-subject SDs
              ACW_grand_mean_s = ("ACW_grand_mean_s", "mean")
          )
)
# Out:
# ================ GROUP-LEVEL SUMMARY ================
# Rows in df_all: 1764
# Unique subjects in df_all: 28
# First few subjects: ['sub-001', 'sub-002', 'sub-004', 'sub-005', 'sub-006', 'sub-007', 'sub-008', 'sub-009', 'sub-010', 'sub-011'] ...
# =====================================================
#
#    Subject Condition Channel  ACW_mean_s  ACW_std_s  ACW_grand_mean_s
# 0  sub-001   GRADCPT     Fp1    0.030824   0.002194          0.030048
# 1  sub-001   GRADCPT     Fp2    0.016193   0.002625          0.030048
# 2  sub-001   GRADCPT      F3    0.031392   0.001044          0.030048
# 3  sub-001   GRADCPT      F4    0.028232   0.004657          0.030048
# 4  sub-001   GRADCPT      C3    0.031641   0.001703          0.030048
